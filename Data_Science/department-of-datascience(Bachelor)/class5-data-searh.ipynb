# %% [markdown]
# 데이터 탐색
# ==
#
# 다루는 내용
# --
# - 데이터 특성 보기, 데이터 탐색, 시각화
# - 클러스터링
#
# 데이터
# --
# - 전력판매량(시도별/용도별) 액셀 파일 https://goo.gl/Cx8Rzw
# - 위 자료는 전력거래소에서 받은 자료임
# - 이 파일을 현재 작업중인 (쥬피터 노트북이 실행되는) 폴더 아래에 data 폴더를 만들고 data 폴더로 복사한다

# %% [markdown]
# 필요한 라이브러리(모듈) 설치
# --

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %% [markdown]
# 데이터 읽기
# --

# %%
power_data = pd.read_excel('data/시도별_용도별.xls')
print(power_data.shape)
# Out:
# (19, 28)

# %%
power_data
# Out:
#     구분       주거용       공공용       서비스업      업무용합계      농림어업       광업  \
# 0   강원   1940933   1400421    6203749    7604170    607139   398287
# 1   개성         0         0          0          0         0        0
# 2   경기  16587710   5533662   33434551   38968213   2371347   317263
# 3   경남   4260988   1427560    8667737   10095297   2141813    95989
# 4   경북   3302463   1578115    8487402   10065517   1747462   224568
# 5   광주   1954876    565527    3174973    3740500     74608     2898
# 6   대구   3151904    826396    5470438    6296834     69142     5858
# 7   대전   1872890    954681    3955921    4910602     28643     3326
# 8   부산   4473510   1305876    7582169    8888045    107927    25289
# 9   서울  13131172   3581534   27647345   31228879     15150     4064
# 10  세종    384903    299675     645424     945099     69469    16364
# 11  울산   1487143    489865    3649386    4139251     80221    20103
# 12  인천   3856852    921748    7154416    8076164    142953    71529
# 13  전남   2284124    964024    5690659    6654683   3096126    73217
# 14  전북   2326183   1096968    4910318    6007286   1415004    85300
# 15  제주    782601    301727    2308732    2610459   1364930    14019
# 16  충남   2691823   1089613    7164439    8254052   1928066   248313
# 17  충북   2027281   1267140    4804638    6071778    721131   139856
# 18  합계  64576423  22204112  134748546  156952658  15373994  1347957
#
#           제조업     식료품제조     섬유,의류  ...      기타기계    사무기기     전기기기     영상,음향  \
# 0     6002286    546621     13027  ...     35063    2019    38062     43986
# 1           0         0         0  ...         0       0        0         0
# 2    56603327   2544420   2109963  ...   3613798  317244  1040171  24519644
# 3    18053778    932743    346974  ...   1902913    8070   924235    534196
# 4    30115601    566071   3780171  ...    782570   14468   750786   4174971
# 5     2910768    161072    295922  ...    198847    5967   236622    723764
# 6     5862633    212626   1057342  ...    516493   58446   180189    252662
# 7     2608343    204171     41687  ...     77970    2949    83609    474561
# 8     7512588    532943    528513  ...    904149    4913   107717     90644
# 9     1918893    227077    497699  ...    163688    4395    11425     46225
# 10    1502922    110211     70617  ...     26185   14319    33539    170366
# 11   25883132    187738    943299  ...    169132    5053   381602     24165
# 12   12367816    641088     75895  ...    942801    7853   178502   1124564
# 13   21453926    511361    160506  ...     66431    1061   149939     42399
# 14   12965875   1459217    731651  ...    159699    7240   130692    420005
# 15     241537    155987      3497  ...      1167       0      771         0
# 16   37057955   1137035    269998  ...    611925   12208   428906  10953811
# 17   15883448   1152073    333846  ...    366871   23076  1125141   4103832
# 18  252942540  10735833  11247578  ...  10504640  487262  5763846  47655808
#
#          자동차     기타운송    가구및기타    재생재료      산업용합계         합계
# 0     113448   108629    12872    3418    7007712   16552816
# 1          0        0        0       0          0          0
# 2    2977165    67594  1833112  133041   59291937  114847859
# 3    2156059  2048646   262523   47662   20291580   34647864
# 4    2356890   123935    60280   77104   32087631   45455611
# 5     512148     5140    13392   16049    2988274    8683649
# 6    1381273    68127    41814   33616    5937633   15386372
# 7     218191     5439    31657    2252    2640312    9423804
# 8    1046529   231141    49733   13104    7645804   21007358
# 9      20182    17656   132707    2875    1938107   46298158
# 10     79009        0     5132    2603    1588755    2918758
# 11   2367150  1020610     4984    1626   25983456   31609850
# 12    612898    54225   360778   32538   12582298   24515313
# 13     72132   481592    14670   31932   24623269   33562076
# 14    859741    70980    16175   99003   14466179   22799647
# 15       773      532     1743     743    1620486    5013545
# 16   2526658    33766    53804   19725   39234334   50180209
# 17    603349    82496   513501   46038   16744435   24843494
# 18  17790147  4311878  3396006  559909  269664491  491193571
#
# [19 rows x 28 columns]

# %%
type(power_data)
# Out:
# pandas.core.frame.DataFrame

# %%
power_data.columns
# Out:
# Index(['구분', '주거용', '공공용', '서비스업', '업무용합계', '농림어업', '광업', '제조업', '식료품제조',
#        '섬유,의류', '목재,나무', '펄프,종이', '출판,인쇄', '석유,화확', '의료,광학', '요업', '1차금속',
#        '조립금속', '기타기계', '사무기기', '전기기기', '영상,음향', '자동차', '기타운송', '가구및기타', '재생재료',
#        '산업용합계', '합계'],
#       dtype='object')

# %%
power = power_data.set_index('구분')

# %%
power = power.drop(['합계', '개성'], errors='ignore')

# %%
power.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17 entries, 강원 to 충북
# Data columns (total 27 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   주거용     17 non-null     int64
#  1   공공용     17 non-null     int64
#  2   서비스업    17 non-null     int64
#  3   업무용합계   17 non-null     int64
#  4   농림어업    17 non-null     int64
#  5   광업      17 non-null     int64
#  6   제조업     17 non-null     int64
#  7   식료품제조   17 non-null     int64
#  8   섬유,의류   17 non-null     int64
#  9   목재,나무   17 non-null     int64
#  10  펄프,종이   17 non-null     int64
#  11  출판,인쇄   17 non-null     int64
#  12  석유,화확   17 non-null     int64
#  13  의료,광학   17 non-null     int64
#  14  요업      17 non-null     int64
#  15  1차금속    17 non-null     int64
#  16  조립금속    17 non-null     int64
#  17  기타기계    17 non-null     int64
#  18  사무기기    17 non-null     int64
#  19  전기기기    17 non-null     int64
#  20  영상,음향   17 non-null     int64
#  21  자동차     17 non-null     int64
#  22  기타운송    17 non-null     int64
#  23  가구및기타   17 non-null     int64
#  24  재생재료    17 non-null     int64
#  25  산업용합계   17 non-null     int64
#  26  합계      17 non-null     int64
# dtypes: int64(27)
# memory usage: 3.7+ KB

# %%
power
# Out:
#         서비스업       제조업
# 구분
# 강원   6203749   6002286
# 경기  33434551  56603327
# 경남   8667737  18053778
# 경북   8487402  30115601
# 광주   3174973   2910768
# 대구   5470438   5862633
# 대전   3955921   2608343
# 부산   7582169   7512588
# 서울  27647345   1918893
# 세종    645424   1502922
# 울산   3649386  25883132
# 인천   7154416  12367816
# 전남   5690659  21453926
# 전북   4910318  12965875
# 제주   2308732    241537
# 충남   7164439  37057955
# 충북   4804638  15883448

# %% [markdown]
# 데이터 특성 보기
# --
# - boxplot
# - barplot
# - histogram

# %% [markdown]
# 박스플롯
# --

# %% [markdown]
# 한글 폰트 설정 (맥, 윈도우, 리눅스)
# --

# %%
import platform
from matplotlib import font_manager,rc
import matplotlib
# '-' 부호가 제대로 표시되게 하는 설정
matplotlib.rcParams['axes.unicode_minus'] = False
# 운영 체제마다 한글이 보이게 하는 설정
# 윈도우
if platform.system() == 'Windows':
    path = "c:\Windows\Fonts\malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font',family=font_name)

# %%
power.describe()
# Out:
#                서비스업           제조업
# count  1.700000e+01  1.700000e+01
# mean   8.291312e+06  1.523205e+07
# std    8.708909e+06  1.524290e+07
# min    6.454240e+05  2.415370e+05
# 25%    3.955921e+06  2.910768e+06
# 50%    5.690659e+06  1.236782e+07
# 75%    7.582169e+06  2.145393e+07
# max    3.343455e+07  5.660333e+07

# %%
power.drop('합계', axis=1).boxplot(figsize=(12,8))
plt.xticks(rotation=45)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-117-8718731bf890> in <module>
# ----> 1 power.drop('합계', axis=1).boxplot(figsize=(12,8))
#       2 plt.xticks(rotation=45)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4161                 weight  1.0     0.8
#    4162         """
# -> 4163         return super().drop(
#    4164             labels=labels,
#    4165             axis=axis,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
#    3889         if inplace:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3919                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3920             else:
# -> 3921                 new_axis = axis.drop(labels, errors=errors)
#    3922             result = self.reindex(**{axis_name: new_axis})
#    3923
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5280         if mask.any():
#    5281             if errors != "ignore":
# -> 5282                 raise KeyError(f"{labels[mask]} not found in axis")
#    5283             indexer = indexer[~mask]
#    5284         return self.delete(indexer)
#
# KeyError: "['합계'] not found in axis"

# %%
power[['서비스업','제조업']].boxplot(figsize=(10,6))
# Out:
# <AxesSubplot:>

# %% [markdown]
# 바 플롯 (수평형)
# --

# %%
power
# Out:
#         서비스업       제조업
# 구분
# 강원   6203749   6002286
# 경기  33434551  56603327
# 경남   8667737  18053778
# 경북   8487402  30115601
# 광주   3174973   2910768
# 대구   5470438   5862633
# 대전   3955921   2608343
# 부산   7582169   7512588
# 서울  27647345   1918893
# 세종    645424   1502922
# 울산   3649386  25883132
# 인천   7154416  12367816
# 전남   5690659  21453926
# 전북   4910318  12965875
# 제주   2308732    241537
# 충남   7164439  37057955
# 충북   4804638  15883448

# %%
power = power.drop('합계', axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-120-3bd415348135> in <module>
# ----> 1 power = power.drop('합계', axis=1)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4161                 weight  1.0     0.8
#    4162         """
# -> 4163         return super().drop(
#    4164             labels=labels,
#    4165             axis=axis,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
#    3889         if inplace:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3919                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3920             else:
# -> 3921                 new_axis = axis.drop(labels, errors=errors)
#    3922             result = self.reindex(**{axis_name: new_axis})
#    3923
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5280         if mask.any():
#    5281             if errors != "ignore":
# -> 5282                 raise KeyError(f"{labels[mask]} not found in axis")
#    5283             indexer = indexer[~mask]
#    5284         return self.delete(indexer)
#
# KeyError: "['합계'] not found in axis"

# %%
power.plot(kind='barh', figsize=(12,8), stacked=True)
# Out:
# <AxesSubplot:ylabel='구분'>

# %%
power = power.drop(['합계', '개성'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-122-f19194d143cc> in <module>
# ----> 1 power = power.drop(['합계', '개성'])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4161                 weight  1.0     0.8
#    4162         """
# -> 4163         return super().drop(
#    4164             labels=labels,
#    4165             axis=axis,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
#    3889         if inplace:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3919                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3920             else:
# -> 3921                 new_axis = axis.drop(labels, errors=errors)
#    3922             result = self.reindex(**{axis_name: new_axis})
#    3923
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5280         if mask.any():
#    5281             if errors != "ignore":
# -> 5282                 raise KeyError(f"{labels[mask]} not found in axis")
#    5283             indexer = indexer[~mask]
#    5284         return self.delete(indexer)
#
# KeyError: "['합계' '개성'] not found in axis"

# %%
power.plot(kind='barh', figsize=(10,6), stacked=True)
# Out:
# <AxesSubplot:ylabel='구분'>

# %%
sample = ['주거용', '공공용', '서비스업', '농림어업', '제조업']
power[sample].plot(kind='barh', figsize=(12,8), stacked=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-124-e541f584e481> in <module>
#       1 sample = ['주거용', '공공용', '서비스업', '농림어업', '제조업']
# ----> 2 power[sample].plot(kind='barh', figsize=(12,8), stacked=True)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2906             if is_iterator(key):
#    2907                 key = list(key)
# -> 2908             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2909
#    2910         # take() does not accept boolean indexers
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# -> 1254         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1255         return keyarr, indexer
#    1256
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1302             if raise_missing:
#    1303                 not_found = list(set(key) - set(ax))
# -> 1304                 raise KeyError(f"{not_found} not in index")
#    1305
#    1306             # we skip the warning on Categorical
#
# KeyError: "['주거용', '공공용', '농림어업'] not in index"

# %%
see2 = [ '서비스업','제조업']
power[see2].plot(kind='barh', figsize=(10,6), stacked=True)
# Out:
# <AxesSubplot:ylabel='구분'>

# %%
power = power[['서비스업', '제조업']]
power.head(5)
# Out:
#         서비스업       제조업
# 구분
# 강원   6203749   6002286
# 경기  33434551  56603327
# 경남   8667737  18053778
# 경북   8487402  30115601
# 광주   3174973   2910768

# %% [markdown]
# 히스토그램
# --

# %%
power['서비스업'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# 스캐터 플롯
# --

# %%
power
# Out:
#         서비스업       제조업
# 구분
# 강원   6203749   6002286
# 경기  33434551  56603327
# 경남   8667737  18053778
# 경북   8487402  30115601
# 광주   3174973   2910768
# 대구   5470438   5862633
# 대전   3955921   2608343
# 부산   7582169   7512588
# 서울  27647345   1918893
# 세종    645424   1502922
# 울산   3649386  25883132
# 인천   7154416  12367816
# 전남   5690659  21453926
# 전북   4910318  12965875
# 제주   2308732    241537
# 충남   7164439  37057955
# 충북   4804638  15883448

# %%
print(power.shape)
# Out:
# (17, 2)

# %%
n_samples = power.shape[0]
n_samples
# Out:
# 17

# %%
print(n_samples)
# Out:
# 17

# %%
plt.figure(figsize=(8,8))
plt.scatter(power['서비스업'], power['제조업'])
plt.xlabel('서비스업')
plt.ylabel('제조업')
# Out:
# Text(0, 0.5, '제조업')

# %%
plt.figure(figsize=(8,8))
plt.scatter(power['서비스업'], power['제조업'],c='k',marker='o')
plt.xlabel('서비스업')
plt.ylabel('제조업')

for n in range(power.shape[0]):
    plt.text(power['서비스업'][n]*1.03, power['제조업'][n]*0.98, power.index[n])

# %%
power = power.drop(['경기', '서울'])

# %%
power
# Out:
#        서비스업       제조업
# 구분
# 강원  6203749   6002286
# 경남  8667737  18053778
# 경북  8487402  30115601
# 광주  3174973   2910768
# 대구  5470438   5862633
# 대전  3955921   2608343
# 부산  7582169   7512588
# 세종   645424   1502922
# 울산  3649386  25883132
# 인천  7154416  12367816
# 전남  5690659  21453926
# 전북  4910318  12965875
# 제주  2308732    241537
# 충남  7164439  37057955
# 충북  4804638  15883448

# %%
plt.figure(figsize=(8,8))
plt.scatter(power['서비스업'], power['제조업'],c='k',marker='o')
plt.xlabel('서비스업')
plt.ylabel('제조업')

for n in range(power.shape[0]):
    plt.text(power['서비스업'][n]*1.03, power['제조업'][n]*0.98, power.index[n])

# %% [markdown]
# # -------------------------------------------

# %%
#필요한 라이브러리(모듈) 설치
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#데이터 읽기
power_data = pd.read_excel('data/HOME_발전·판매_판매전력량_시도별용도별.xlsx') #tab을 눌러서 위치를 확인할 수 있다.
print(power_data.shape)
# Out:
# (21, 28)

# %%
power_data
# Out:
#      구분           주거용          업무용   Unnamed: 3   Unnamed: 4          산업용  \
# 0   NaN           NaN          공공용         서비스업        업무용 계         농림어업
# 1   NaN           NaN          NaN          NaN          NaN          NaN
# 2    강원  2.081091e+06  1.43543e+06  6.29591e+06  7.73134e+06       693533
# 3    개성  1.059430e+02      2403.61      1275.99      3679.59            0
# 4    경기  1.822849e+07  5.76801e+06  3.56604e+07  4.14284e+07   2.6054e+06
# 5    경남  4.475992e+06  1.45643e+06  8.73362e+06  1.01901e+07  2.21189e+06
# 6    경북  3.466430e+06  1.66127e+06  8.52614e+06  1.01874e+07  1.92767e+06
# 7    광주  2.038974e+06       574010  3.20739e+06   3.7814e+06      74320.3
# 8    대구  3.252483e+06       852760  5.54282e+06  6.39558e+06      71232.2
# 9    대전  1.938646e+06  1.04276e+06  4.06448e+06  5.10724e+06      32480.6
# 10   부산  4.624742e+06  1.33299e+06  7.53367e+06  8.86666e+06       110821
# 11   서울  1.349907e+07   3.6973e+06  2.83406e+07  3.20379e+07      15193.9
# 12   세종  5.077077e+05       329516       766782   1.0963e+06      81894.8
# 13   울산  1.546257e+06       479123  3.57687e+06  4.05599e+06      80392.3
# 14   인천  4.121503e+06       947488  7.62727e+06  8.57475e+06       151959
# 15   전남  2.358630e+06  1.00029e+06      6049218  7.04951e+06  3.26852e+06
# 16   전북  2.397330e+06  1.11731e+06  5.03664e+06  6.15395e+06  1.53783e+06
# 17   제주  8.509886e+05       323855  2.47154e+06   2.7954e+06  1.46819e+06
# 18   충남  2.887132e+06  1.12146e+06  7.37537e+06  8.49683e+06   2.1363e+06
# 19   충북  2.179834e+06  1.31576e+06  5.00566e+06  6.32141e+06       837037
# 20   합계  7.045541e+07  2.44581e+07  1.45816e+08  1.70274e+08  1.73047e+07
#
#      Unnamed: 6   Unnamed: 7   Unnamed: 8   Unnamed: 9  ... Unnamed: 18  \
# 0            광업          제조업          NaN          NaN  ...         NaN
# 1           NaN        식료품제조        섬유,의류        목재,나무  ...        사무기기
# 2        408545       581065      12215.5      19164.8  ...     1289.78
# 3             0            0            0            0  ...           0
# 4        274639  2.78004e+06  1.92182e+06       476956  ...      232628
# 5         67524       978524       322642      57654.1  ...     5307.19
# 6        200766       614329  3.37752e+06      69724.2  ...     7635.38
# 7       1779.94       167493       211957       6545.8  ...     4851.91
# 8        6673.3       223845       900120        16432  ...     57693.7
# 9       982.453       211245      36474.6      4060.42  ...     2487.32
# 10      18191.2       555790       433742      44824.3  ...      182.69
# 11      2067.14       227437       461353      3977.93  ...     2700.88
# 12      13779.4       112225      28412.1      1167.63  ...     16345.6
# 13      13075.8       187021       840008      14526.6  ...     4573.44
# 14        46549       652576      58875.5       564367  ...     2755.82
# 15      73913.4       559594       182089      24494.6  ...     585.107
# 16      64056.2  1.65537e+06       626431       254559  ...     2015.14
# 17      4308.58       162236      5262.89      1179.56  ...           0
# 18       172239  1.31265e+06       245163       126049  ...     10219.3
# 19       123427  1.25092e+06       271869      48848.3  ...     11751.2
# 20  1.49252e+06  1.22324e+07  9.93596e+06  1.73453e+06  ...      363023
#
#     Unnamed: 19  Unnamed: 20  Unnamed: 21  Unnamed: 22  Unnamed: 23  \
# 0           NaN          NaN          NaN          NaN          NaN
# 1          전기기기        영상,음향          자동차         기타운송        가구및기타
# 2         35330      43875.6       119820       101151      13386.8
# 3             0            0            0            0            0
# 4        987827  2.79808e+07  2.87264e+06      94631.2  2.22799e+06
# 5        942620       480832  2.10432e+06  1.97297e+06       339035
# 6        813989  3.97447e+06  2.36149e+06       130965      63632.3
# 7        230318       697747       478040      5835.84      20532.6
# 8        197825       197754  1.33204e+06      49575.8      41574.3
# 9       78919.7       231436       198962      7594.42      35667.6
# 10       119882        93634  1.15895e+06       222043      43164.2
# 11      9277.61      27802.8      18403.2      22955.3       129892
# 12      28814.5       177269      81835.1       35.201      4427.74
# 13       429728      29342.5  2.41185e+06  1.03879e+06      4803.58
# 14       159723  1.02747e+06       518577      53753.1       498934
# 15       251400      40087.6      71048.1       553848      17400.8
# 16       142438       432136       758650        36571      15139.1
# 17      843.995        9.931      801.273      476.503      1992.67
# 18       888663  1.14318e+07  2.35325e+06      34173.1       102551
# 19  1.38814e+06  4.69498e+06       628623      58590.5       722413
# 20  6.70574e+06  5.15615e+07  1.74693e+07  4.38397e+06  4.28254e+06
#
#    Unnamed: 24  Unnamed: 25  Unnamed: 26            합계
# 0          NaN          NaN        산업용 계           NaN
# 1         재생재료        제조업 계          NaN           NaN
# 2      3414.79  5.45377e+06  6.55584e+06  1.636827e+07
# 3            0            0            0  3.785534e+03
# 4       134107  6.04854e+07  6.33654e+07  1.230223e+08
# 5      50607.8  1.75266e+07   1.9806e+07  3.447202e+07
# 6      73340.5  2.85325e+07  3.06609e+07  4.431477e+07
# 7      16448.5  2.70682e+06  2.78292e+06  8.603297e+06
# 8      50978.4  5.53962e+06  5.61752e+06  1.526558e+07
# 9      1904.76  2.33635e+06  2.36982e+06  9.415699e+06
# 10     11995.9    7.182e+06  7.31101e+06  2.080241e+07
# 11     3079.54  1.61293e+06  1.63019e+06  4.716721e+07
# 12     2581.84   1.5265e+06  1.62217e+06  3.226179e+06
# 13     2050.09  2.84433e+07  2.85368e+07  3.413900e+07
# 14     28766.3  1.13859e+07  1.15844e+07  2.428069e+07
# 15       35120  1.96348e+07  2.29772e+07  3.238539e+07
# 16     99298.9  1.21275e+07  1.37294e+07  2.228069e+07
# 17     1037.94       255401   1.7279e+06  5.374285e+06
# 18     20144.7  3.89524e+07  4.12609e+07  5.264485e+07
# 19     40589.5  1.72706e+07  1.82311e+07  2.673230e+07
# 20      575466  2.60972e+08  2.79769e+08  5.204987e+08
#
# [21 rows x 28 columns]

# %%
type(power_data)
# Out:
# pandas.core.frame.DataFrame

# %%
power_data.columns
# Out:
# Index(['구분', '주거용', '업무용', 'Unnamed: 3', 'Unnamed: 4', '산업용', 'Unnamed: 6',
#        'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11',
#        'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15',
#        'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19',
#        'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23',
#        'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26', '합계'],
#       dtype='object')

# %%
power_data
# Out:
#      구분           주거용          업무용   Unnamed: 3   Unnamed: 4          산업용  \
# 0   NaN           NaN          공공용         서비스업        업무용 계         농림어업
# 1   NaN           NaN          NaN          NaN          NaN          NaN
# 2    강원  2.081091e+06  1.43543e+06  6.29591e+06  7.73134e+06       693533
# 3    개성  1.059430e+02      2403.61      1275.99      3679.59            0
# 4    경기  1.822849e+07  5.76801e+06  3.56604e+07  4.14284e+07   2.6054e+06
# 5    경남  4.475992e+06  1.45643e+06  8.73362e+06  1.01901e+07  2.21189e+06
# 6    경북  3.466430e+06  1.66127e+06  8.52614e+06  1.01874e+07  1.92767e+06
# 7    광주  2.038974e+06       574010  3.20739e+06   3.7814e+06      74320.3
# 8    대구  3.252483e+06       852760  5.54282e+06  6.39558e+06      71232.2
# 9    대전  1.938646e+06  1.04276e+06  4.06448e+06  5.10724e+06      32480.6
# 10   부산  4.624742e+06  1.33299e+06  7.53367e+06  8.86666e+06       110821
# 11   서울  1.349907e+07   3.6973e+06  2.83406e+07  3.20379e+07      15193.9
# 12   세종  5.077077e+05       329516       766782   1.0963e+06      81894.8
# 13   울산  1.546257e+06       479123  3.57687e+06  4.05599e+06      80392.3
# 14   인천  4.121503e+06       947488  7.62727e+06  8.57475e+06       151959
# 15   전남  2.358630e+06  1.00029e+06      6049218  7.04951e+06  3.26852e+06
# 16   전북  2.397330e+06  1.11731e+06  5.03664e+06  6.15395e+06  1.53783e+06
# 17   제주  8.509886e+05       323855  2.47154e+06   2.7954e+06  1.46819e+06
# 18   충남  2.887132e+06  1.12146e+06  7.37537e+06  8.49683e+06   2.1363e+06
# 19   충북  2.179834e+06  1.31576e+06  5.00566e+06  6.32141e+06       837037
# 20   합계  7.045541e+07  2.44581e+07  1.45816e+08  1.70274e+08  1.73047e+07
#
#      Unnamed: 6   Unnamed: 7   Unnamed: 8   Unnamed: 9  ... Unnamed: 18  \
# 0            광업          제조업          NaN          NaN  ...         NaN
# 1           NaN        식료품제조        섬유,의류        목재,나무  ...        사무기기
# 2        408545       581065      12215.5      19164.8  ...     1289.78
# 3             0            0            0            0  ...           0
# 4        274639  2.78004e+06  1.92182e+06       476956  ...      232628
# 5         67524       978524       322642      57654.1  ...     5307.19
# 6        200766       614329  3.37752e+06      69724.2  ...     7635.38
# 7       1779.94       167493       211957       6545.8  ...     4851.91
# 8        6673.3       223845       900120        16432  ...     57693.7
# 9       982.453       211245      36474.6      4060.42  ...     2487.32
# 10      18191.2       555790       433742      44824.3  ...      182.69
# 11      2067.14       227437       461353      3977.93  ...     2700.88
# 12      13779.4       112225      28412.1      1167.63  ...     16345.6
# 13      13075.8       187021       840008      14526.6  ...     4573.44
# 14        46549       652576      58875.5       564367  ...     2755.82
# 15      73913.4       559594       182089      24494.6  ...     585.107
# 16      64056.2  1.65537e+06       626431       254559  ...     2015.14
# 17      4308.58       162236      5262.89      1179.56  ...           0
# 18       172239  1.31265e+06       245163       126049  ...     10219.3
# 19       123427  1.25092e+06       271869      48848.3  ...     11751.2
# 20  1.49252e+06  1.22324e+07  9.93596e+06  1.73453e+06  ...      363023
#
#     Unnamed: 19  Unnamed: 20  Unnamed: 21  Unnamed: 22  Unnamed: 23  \
# 0           NaN          NaN          NaN          NaN          NaN
# 1          전기기기        영상,음향          자동차         기타운송        가구및기타
# 2         35330      43875.6       119820       101151      13386.8
# 3             0            0            0            0            0
# 4        987827  2.79808e+07  2.87264e+06      94631.2  2.22799e+06
# 5        942620       480832  2.10432e+06  1.97297e+06       339035
# 6        813989  3.97447e+06  2.36149e+06       130965      63632.3
# 7        230318       697747       478040      5835.84      20532.6
# 8        197825       197754  1.33204e+06      49575.8      41574.3
# 9       78919.7       231436       198962      7594.42      35667.6
# 10       119882        93634  1.15895e+06       222043      43164.2
# 11      9277.61      27802.8      18403.2      22955.3       129892
# 12      28814.5       177269      81835.1       35.201      4427.74
# 13       429728      29342.5  2.41185e+06  1.03879e+06      4803.58
# 14       159723  1.02747e+06       518577      53753.1       498934
# 15       251400      40087.6      71048.1       553848      17400.8
# 16       142438       432136       758650        36571      15139.1
# 17      843.995        9.931      801.273      476.503      1992.67
# 18       888663  1.14318e+07  2.35325e+06      34173.1       102551
# 19  1.38814e+06  4.69498e+06       628623      58590.5       722413
# 20  6.70574e+06  5.15615e+07  1.74693e+07  4.38397e+06  4.28254e+06
#
#    Unnamed: 24  Unnamed: 25  Unnamed: 26            합계
# 0          NaN          NaN        산업용 계           NaN
# 1         재생재료        제조업 계          NaN           NaN
# 2      3414.79  5.45377e+06  6.55584e+06  1.636827e+07
# 3            0            0            0  3.785534e+03
# 4       134107  6.04854e+07  6.33654e+07  1.230223e+08
# 5      50607.8  1.75266e+07   1.9806e+07  3.447202e+07
# 6      73340.5  2.85325e+07  3.06609e+07  4.431477e+07
# 7      16448.5  2.70682e+06  2.78292e+06  8.603297e+06
# 8      50978.4  5.53962e+06  5.61752e+06  1.526558e+07
# 9      1904.76  2.33635e+06  2.36982e+06  9.415699e+06
# 10     11995.9    7.182e+06  7.31101e+06  2.080241e+07
# 11     3079.54  1.61293e+06  1.63019e+06  4.716721e+07
# 12     2581.84   1.5265e+06  1.62217e+06  3.226179e+06
# 13     2050.09  2.84433e+07  2.85368e+07  3.413900e+07
# 14     28766.3  1.13859e+07  1.15844e+07  2.428069e+07
# 15       35120  1.96348e+07  2.29772e+07  3.238539e+07
# 16     99298.9  1.21275e+07  1.37294e+07  2.228069e+07
# 17     1037.94       255401   1.7279e+06  5.374285e+06
# 18     20144.7  3.89524e+07  4.12609e+07  5.264485e+07
# 19     40589.5  1.72706e+07  1.82311e+07  2.673230e+07
# 20      575466  2.60972e+08  2.79769e+08  5.204987e+08
#
# [21 rows x 28 columns]

# %%
power_data.head()
# Out:
#     구분           주거용          업무용   Unnamed: 3   Unnamed: 4         산업용  \
# 0  NaN           NaN          공공용         서비스업        업무용 계        농림어업
# 1  NaN           NaN          NaN          NaN          NaN         NaN
# 2   강원  2.081091e+06  1.43543e+06  6.29591e+06  7.73134e+06      693533
# 3   개성  1.059430e+02      2403.61      1275.99      3679.59           0
# 4   경기  1.822849e+07  5.76801e+06  3.56604e+07  4.14284e+07  2.6054e+06
#
#   Unnamed: 6   Unnamed: 7   Unnamed: 8 Unnamed: 9  ... Unnamed: 18  \
# 0         광업          제조업          NaN        NaN  ...         NaN
# 1        NaN        식료품제조        섬유,의류      목재,나무  ...        사무기기
# 2     408545       581065      12215.5    19164.8  ...     1289.78
# 3          0            0            0          0  ...           0
# 4     274639  2.78004e+06  1.92182e+06     476956  ...      232628
#
#   Unnamed: 19  Unnamed: 20  Unnamed: 21 Unnamed: 22  Unnamed: 23 Unnamed: 24  \
# 0         NaN          NaN          NaN         NaN          NaN         NaN
# 1        전기기기        영상,음향          자동차        기타운송        가구및기타        재생재료
# 2       35330      43875.6       119820      101151      13386.8     3414.79
# 3           0            0            0           0            0           0
# 4      987827  2.79808e+07  2.87264e+06     94631.2  2.22799e+06      134107
#
#    Unnamed: 25  Unnamed: 26            합계
# 0          NaN        산업용 계           NaN
# 1        제조업 계          NaN           NaN
# 2  5.45377e+06  6.55584e+06  1.636827e+07
# 3            0            0  3.785534e+03
# 4  6.04854e+07  6.33654e+07  1.230223e+08
#
# [5 rows x 28 columns]

# %%
power = power_data.drop(['합계','개성'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-87-a74553173513> in <module>
# ----> 1 power = power_data.drop(['합계','개성'])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4161                 weight  1.0     0.8
#    4162         """
# -> 4163         return super().drop(
#    4164             labels=labels,
#    4165             axis=axis,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
#    3889         if inplace:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3919                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3920             else:
# -> 3921                 new_axis = axis.drop(labels, errors=errors)
#    3922             result = self.reindex(**{axis_name: new_axis})
#    3923
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5280         if mask.any():
#    5281             if errors != "ignore":
# -> 5282                 raise KeyError(f"{labels[mask]} not found in axis")
#    5283             indexer = indexer[~mask]
#    5284         return self.delete(indexer)
#
# KeyError: "['합계' '개성'] not found in axis"

# %%
power.T
# Out:
# 구분         강원        경남        경북       광주       대구       대전       부산  \
# 서비스업  6203749   8667737   8487402  3174973  5470438  3955921  7582169
# 제조업   6002286  18053778  30115601  2910768  5862633  2608343  7512588
#
# 구분         세종        울산        인천        전남        전북       제주        충남  \
# 서비스업   645424   3649386   7154416   5690659   4910318  2308732   7164439
# 제조업   1502922  25883132  12367816  21453926  12965875   241537  37057955
#
# 구분          충북
# 서비스업   4804638
# 제조업   15883448

# %%
power.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15 entries, 강원 to 충북
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   서비스업    15 non-null     int64
#  1   제조업     15 non-null     int64
# dtypes: int64(2)
# memory usage: 1000.0+ bytes

# %%
import platform
platform.system()
# 운영체제별 한글 폰트 설정
if platform.system() == 'Darwin': # Mac 환경 폰트 설정
    plt.rc('font', family='AppleGothic')
elif platform.system() == 'Windows': # Windows 환경 폰트 설정
    plt.rc('font', family='Malgun Gothic')

# %%
power.describe()
# Out:
#                서비스업           제조업
# count  1.500000e+01  1.500000e+01
# mean   5.324693e+06  1.336151e+07
# std    2.309461e+06  1.126382e+07
# min    6.454240e+05  2.415370e+05
# 25%    3.802654e+06  4.386700e+06
# 50%    5.470438e+06  1.236782e+07
# 75%    7.159428e+06  1.975385e+07
# max    8.667737e+06  3.705796e+07

# %%
power.drop('합계',axis=1).boxplot(figsize=(12,8))
plt.xticks(rotation=45)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-62-0ba25a67509f> in <module>
# ----> 1 power.drop('합계',axis=1).boxplot(figsize=(12,8))
#       2 plt.xticks(rotation=45)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4161                 weight  1.0     0.8
#    4162         """
# -> 4163         return super().drop(
#    4164             labels=labels,
#    4165             axis=axis,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
#    3889         if inplace:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3919                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3920             else:
# -> 3921                 new_axis = axis.drop(labels, errors=errors)
#    3922             result = self.reindex(**{axis_name: new_axis})
#    3923
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5280         if mask.any():
#    5281             if errors != "ignore":
# -> 5282                 raise KeyError(f"{labels[mask]} not found in axis")
#    5283             indexer = indexer[~mask]
#    5284         return self.delete(indexer)
#
# KeyError: "['합계'] not found in axis"

# %%
power[['서비스업','제조업']].boxplot(figsize=(10,6))
# Out:
# <AxesSubplot:>

# %%
power.plot(kind='barh', figsize=(12,8), stacked=True)
# Out:
# <AxesSubplot:ylabel='구분'>

# %%
sample= ['주거용']  #일부만 가져오고 싶다
power[sample].plot(kind='barh', figsize=(12,8), stacked=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-65-5dd5f9970ea4> in <module>
#       1 sample= ['주거용']  #일부만 가져오고 싶다
# ----> 2 power[sample].plot(kind='barh', figsize=(12,8), stacked=True)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2906             if is_iterator(key):
#    2907                 key = list(key)
# -> 2908             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2909
#    2910         # take() does not accept boolean indexers
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# -> 1254         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1255         return keyarr, indexer
#    1256
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1296             if missing == len(indexer):
#    1297                 axis_name = self.obj._get_axis_name(axis)
# -> 1298                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1299
#    1300             # We (temporarily) allow for some missing keys with .loc, except in
#
# KeyError: "None of [Index(['주거용'], dtype='object')] are in the [columns]"

# %%
power =power[['서비스업', '제조업']]
power.head()

# %%
power['주거용'].hist()

# %%
#스캐터 플롯
print(power.shape)

# %%
power.shape[0]
# Out:
# 15

# %%
n_samples = power.shape[0]
n_samples
# Out:
# 15

# %%
print(n_samples)
# Out:
# 15

# %%
plt.figure(figsize=(4,4))
plt.scatter(power['제조업'], power['서비스업'])
plt.xlabel('제조업')
plt.ylabel('서비스업')
# Out:
# Text(0, 0.5, '서비스업')

# %%
power.shape
# Out:
# (15, 2)

# %%
plt.figure(figsize=(8,8))
plt.scatter(power['서비스업'], power['제조업'], c='k', marker='o')
plt.xlabel('서비스업')
plt.ylabel('제조업')

for n in range(power.shape[0]):
    plt.text(power['서비스업'][n]*1.03, power['제조업'][n]*0.98,
            power.index[n])

# %%
power = power.drop(['경기', '서울'], errors='ignore')

# %%
power
# Out:
#        서비스업       제조업
# 구분
# 강원  6203749   6002286
# 경남  8667737  18053778
# 경북  8487402  30115601
# 광주  3174973   2910768
# 대구  5470438   5862633
# 대전  3955921   2608343
# 부산  7582169   7512588
# 세종   645424   1502922
# 울산  3649386  25883132
# 인천  7154416  12367816
# 전남  5690659  21453926
# 전북  4910318  12965875
# 제주  2308732    241537
# 충남  7164439  37057955
# 충북  4804638  15883448

# %%
plt.figure(figsize=(6,6))
plt.scatter(power['서비스업'], power['제조업'], c='k', marker='o')
plt.xlabel('서비스업')
plt.ylabel('제조업')

for n in range(power.shape[0]):
    plt.text(power['서비스업'][n]*1.03, power['제조업'][n]*0.98,
            power.index[n])
